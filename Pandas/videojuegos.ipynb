# %%
import pandas as pd

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
df = pd.read_csv('https://raw.githubusercontent.com/irojasgo/oop_python/main/vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#El juego mas vendido de todos (global sales)
df.sort_values(by='Global_Sales', ascending=False).iloc[0]['Name']
# Out:
# 'Wii Sports'

# %%
#la cantidad total de juegos de deportes (Sports)
pd.DataFrame(df['Genre'] == 'Sports').value_counts()
#df.groupby(by = 'Genre')['Sports'].value_counts()
# Out:
# Genre
# False    14252
# True      2346
# dtype: int64

# %%
import seaborn as sms

# %%
sms.pairplot(df)

# %%
sms.boxplot(df['Year'])
# Out:
# <Axes: >

# %%
sms.displot(df['Year'])

# %%
sms.kdeplot(df['Year'], fill=True, hue=df['Platform'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sms.kdeplot(df['Year'], fill=True, hue=df['Platform'])
#
# File c:\Python311\Lib\site-packages\seaborn\distributions.py:1685, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1681 levels = kwargs.pop("n_levels", levels)
#    1683 # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
# -> 1685 p = _DistributionPlotter(
#    1686     data=data,
#    1687     variables=_DistributionPlotter.get_semantics(locals()),
#    1688 )
#    1690 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1692 if ax is None:
#
# ...
