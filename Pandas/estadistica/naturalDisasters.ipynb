# %%
import pandas as pd
df = pd.read_csv('NaturalDisasters.csv', encoding='latin-1')
df.head(20)
# Out:
#            DisNo. Historic Classification Key Disaster Group  \
# 0   1950-0001-PAK      Yes    nat-hyd-flo-riv        Natural
# 1   1950-0005-PER      Yes    nat-geo-ear-gro        Natural
# 2   1950-0006-IND      Yes    nat-hyd-flo-riv        Natural
# 3   1950-0007-CHN      Yes    nat-hyd-flo-flo        Natural
# 4   1950-0008-IND      Yes    nat-geo-ear-gro        Natural
# 5   1950-0009-ATG      Yes    nat-met-sto-tro        Natural
# 6   1950-0010-JPN      Yes    nat-met-sto-tro        Natural
# 7   1950-0011-IND      Yes    nat-met-sto-sto        Natural
# 8   1950-0012-CAN      Yes    nat-met-sto-tor        Natural
# 9   1950-0013-USA      Yes    nat-met-sto-sto        Natural
# 10  1950-0014-USA      Yes    tec-tra-rai-rai  Technological
# 11  1950-0015-JPN      Yes    tec-ind-poi-poi  Technological
# 12  1950-0016-DDR      Yes    tec-tra-rai-rai  Technological
# 13  1950-0017-CAN      Yes    nat-hyd-flo-flo        Natural
# ...

# %%
df.columns
# Out:
# Index(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion', 'Region',
#        'Location', 'Origin', 'Associated Types', 'OFDA Response', 'Appeal',
#        'Declaration', 'AID Contribution ('000 US$)', 'Magnitude',
#        'Magnitude Scale', 'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damage ('000 US$)', 'Insured Damage, Adjusted ('000 US$)',
#        'Total Damage ('000 US$)', 'Total Damage, Adjusted ('000 US$)', 'CPI',
#        'Admin Units', 'Entry Date', 'Last Update'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25498 entries, 0 to 25497
# Data columns (total 46 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   DisNo.                                     25498 non-null  object
#  1   Historic                                   25498 non-null  object
#  2   Classification Key                         25498 non-null  object
#  3   Disaster Group                             25498 non-null  object
#  4   Disaster Subgroup                          25498 non-null  object
#  5   Disaster Type                              25498 non-null  object
#  6   Disaster Subtype                           25498 non-null  object
#  7   External IDs                               2375 non-null   object
#  8   Event Name                                 8000 non-null   object
#  9   ISO                                        25498 non-null  object
# ...

# %%
df.shape
# Out:
# (25498, 46)

# %%
df['Disaster Type'].value_counts()
# Out:
# Flood                               5869
# Storm                               4553
# Road                                2875
# Water                               1611
# Epidemic                            1499
# Earthquake                          1362
# Air                                  935
# Mass movement (wet)                  804
# Drought                              775
# Fire (Miscellaneous)                 770
# Explosion (Industrial)               744
# Extreme temperature                  648
# Rail                                 620
# Wildfire                             461
# Collapse (Miscellaneous)             299
# Miscellaneous accident (General)     274
# Volcanic activity                    252
# Explosion (Miscellaneous)            220
# Fire (Industrial)                    218
# Collapse (Industrial)                184
# Industrial accident (General)        123
# Chemical spill                       108
# Infestation                           92
# ...

# %%
df[(df['Disaster Group']=='Natural')]['Disaster Type'].value_counts()
# Out:
# Flood                          5869
# Storm                          4553
# Epidemic                       1499
# Earthquake                     1362
# Mass movement (wet)             804
# Drought                         775
# Extreme temperature             648
# Wildfire                        461
# Volcanic activity               252
# Infestation                      92
# Mass movement (dry)              41
# Glacial lake outburst flood       4
# Fog                               1
# Impact                            1
# Animal incident                   1
# Name: Disaster Type, dtype: int64

# %%
df[(df['Disaster Group']=='Technological')]['Disaster Type'].value_counts()
# Out:
# Road                                2875
# Water                               1611
# Air                                  935
# Fire (Miscellaneous)                 770
# Explosion (Industrial)               744
# Rail                                 620
# Collapse (Miscellaneous)             299
# Miscellaneous accident (General)     274
# Explosion (Miscellaneous)            220
# Fire (Industrial)                    218
# Collapse (Industrial)                184
# Industrial accident (General)        123
# Chemical spill                       108
# Poisoning                             76
# Gas leak                              61
# Radiation                              9
# Oil spill                              8
# Name: Disaster Type, dtype: int64

# %%
registros2020 = df[(df['DisNo.'].str.startswith('2020'))&(df['Disaster Group']=='Natural')]
registros2020['Disaster Type'].value_counts()
# Out:
# Flood                  202
# Storm                  128
# Mass movement (wet)     19
# Earthquake              16
# Drought                 12
# Wildfire                 9
# Epidemic                 7
# Extreme temperature      5
# Volcanic activity        4
# Infestation              2
# Name: Disaster Type, dtype: int64

# %%
df['Historic']=="Yes"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25493    False
# 25494    False
# 25495    False
# 25496    False
# 25497    False
# Name: Historic, Length: 25498, dtype: bool
