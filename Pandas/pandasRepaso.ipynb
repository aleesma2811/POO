# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
df = pd.read_csv('https://raw.githubusercontent.com/irojasgo/oop_python/main/netflix_titles.csv')

df.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
#Cuales son las columnas del set de datos?
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info() #Si, hay columnas que tienen datos nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#Cuales son las dimensiones del set de datos?
df.shape
# Out:
# (8807, 12)

# %%
#Dataset de peliculas emitidas en estados unidos
df[(df['country']=='United States')&(df['type']=='Movie')].value_counts()
# Out:
# show_id  type   title                                       director                   cast                                                                                                                                                                                                                     country        date_added          release_year  rating  duration  listed_in                                             description
# ...

# %%
#Series con rating TV-MA en Japon
df[(df['rating']=='TV-MA')&(df['country']=='Japan')]
# Out:
#      show_id     type                                        title  \
# 154     s155  TV Show                          Kuroko's Basketball
# 453     s454  TV Show                                     BEASTARS
# 524     s525  TV Show                Midnight Diner: Tokyo Stories
# 642     s643  TV Show                           The Naked Director
# 675     s676  TV Show                                    REA(L)OVE
# ...      ...      ...                                          ...
# 6846   s6847    Movie                                   Ghost Pain
# 6848   s6849    Movie                                  Ghost Tears
# 7155   s7156  TV Show                                            K
# 7217   s7218  TV Show                           Knights of Sidonia
# 7627   s7628  TV Show  Nura: Rise of the Yokai Clan: Demon Capital
#
#                              director  \
# 154                               NaN
# 453                               NaN
# 524                               NaN
# ...

# %%
#Cantidad de shows por rating
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
#Cantidad de shows por pais
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
#Cuantas peliculas salieron en Mexico en el año 2021
len(df[(df['country']=='Mexico')&(df['release_year']==2021)&(df['type']=='Movie')])
# Out:
# 3

# %%
#Cual es el rating mas comun de estas peliculas
df[(df['country']=='Mexico')&(df['release_year']==2021)]['rating'].value_counts()
# Out:
# rating
# TV-MA    8
# TV-Y7    1
# Name: count, dtype: int64

# %%
#EL mes donde mas peliculas salieron en estados unidos
df['date_added'] = pd.to_datetime(df['date_added'])
df['month_released'] = df['date_added'].dt.month_name() #Crear columna,
df['month_released'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #EL mes donde mas peliculas salieron en estados unidos
# ----> 2 df['date_added'] = pd.to_datetime(df['date_added'])
#       3 df['month_released'] = df['date_added'].dt.month_name() #Crear columna,
#       4 df['month_released'].value_counts()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106             result = arg.tz_localize("utc")
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#    1110         result = arg.map(cache_array)
#
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df['month_released'] = df['date_added'].dt.month_name() #Crear columna,
df[(df['country']=='United States')&(df['month_released'])].value_counts()
# Out:
# show_id  type   title                                                 director                  cast                                                                                                                                                                                                                     country        date_added  release_year  rating  duration  listed_in                                   description                                                                                                                                              month_released
# ...

# %%
#Quien es la persona en Mexico que mas Shows de standup tiene en Netflix? (usar la columna cast para responder esto, en caso de haber un empate, indicar a todos aquellas personas que tienen mas shows de standup en Mexico)
df[(df['country']=='Mexico')&(df['listed_in']=='Stand-Up Comedy')]['cast'].value_counts()
# Out:
# Alan Saldaña                                                                                       2
# Alex Fernández                                                                                     2
# Daniel Sosa                                                                                        2
# Franco Escamilla                                                                                   2
# Carlos Ballarta                                                                                    2
# Sofía Niño de Rivera                                                                               2
# Coco Celis, Raúl Meneses                                                                           1
# Mau Nieto                                                                                          1
# Alexis de Anda                                                                                     1
# ...

# %%
#Ordenar los shows de standup en Mexico por duracion, indicar los 3 shows que duran mas tiempo
df[(df['country']=='Mexico')&(df['listed_in']=='Stand-Up Comedy')].sort_values(by='duration', ascending=False).head(3)
# Out:
#      show_id   type                            title                director  \
# 5872   s5873  Movie  Ricardo O'Farrill Abrazo Genial  Raúl Campos, Jan Suter
# 5839   s5840  Movie    Sofía Niño de Rivera: Exposed  Raúl Campos, Jan Suter
# 5614   s5615  Movie            Daniel Sosa: Sosafado  Raúl Campos, Jan Suter
#
#                       cast country date_added  release_year rating duration  \
# 5872     Ricardo O'Farrill  Mexico 2016-01-22          2016  TV-MA   92 min
# 5839  Sofía Niño de Rivera  Mexico 2016-06-24          2016  TV-MA   80 min
# 5614           Daniel Sosa  Mexico 2017-02-03          2017  TV-MA   78 min
#
#             listed_in                                        description  \
# 5872  Stand-Up Comedy  Ricardo O'Farrill brings his sharp, observatio...
# 5839  Stand-Up Comedy  Self-deprecating comic Sofía Niño de Rivera pu...
# 5614  Stand-Up Comedy  Comedian Daniel Sosa inhabits various characte...
#
#      month_released dia_semana
# ...

# %%
df['dia_semana'] = df['date_added'].dt.day_name()
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
#Indicar el dia de la semana en que fueron estrenados los 3 shows de standup con mas duracion en Mexico (la respuesta debe decir si salieron en lunes, martes, miercoles, etc.)
df[(df['country']=='Mexico')&(df['listed_in']=='Stand-Up Comedy')]
